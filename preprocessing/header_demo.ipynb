# %%
import numpy as np
import pandas as pd
from pandas.tseries.offsets import DateOffset
import matplotlib.pyplot as plt
import datetime
from pathlib import Path # System agnostic paths

import requests # for url requests
import json # for json reading/writing
import time # for epoch timestamp
import csv # for writing csv files

import os

'''
    NOTE: you must sign up for your own EPA Now key and 
    put it along with the password in the file api_key.txt
'''

with open("../api_key.txt") as f:
    email, pwd = f.read().split(",")

# %%
url = 'https://aqs.epa.gov/data/api/sampleData/bySite?'

with open("AirNow_payloads.txt") as f:
    f.readline() # skip header
    for lines in f:
        try:
            param, bdate, edate, state, county, site, fname = lines.split(",")

            keys = {
            'email': email, #for access to the api
            'key': pwd, #for access to the api
            'param': param, #88500 ("PM2.5 Total Atmospheric" for CU Athens) or 88101 ("PM2.5 Local Conditions" for Longmont)
            'bdate': bdate, #begin date (modify as needed, YYYYMMDD)
            'edate': edate, #end date (modify as needed, YYYYMMDD)
            'state': state, #Colorado
            'county': county, #Boulder County
            'site': site, #1001 (for CU Athens) or 0003 (for Longmont)
            }

            print(f"[info]: START processing (start={bdate}, end={edate}, state={state}, county={county}, site={site}) > {fname}")
            query_AirNow = requests.get(url, keys).json()

            if len(fname.split('/')) > 1: # mk folder if necessary
                os.makedirs(f"../data/{'/'.join(fname.split('/')[:-1])}", exist_ok=True)
        
            json.dump(query_AirNow['Data'], open(f"../data/{fname}".strip(), "w")) 

            data_extract = pd.DataFrame(query_AirNow['Data'])

            if not data_extract.empty:
                #Label for csv file
                metadata = ['site_number','latitude', 'longitude', 'method_type', 'method','state', 'county']
                metadata_d = data_extract[metadata].iloc[0].to_dict()
                metadata_d['date_start'] = bdate
                metadata_d['date_end'] = edate

                with open(f"../data/{fname}".strip().replace(".json", ".csv"), "w") as fo:
                    fo.write(
                        '\n'.join([f'## {k.upper()} : {v}' for k, v in metadata_d.items()])
                    )
                    fo.write('\n')

                output_data = pd.DataFrame(columns=['date', 'sample_measurement'])        
                output_data['date'] = pd.to_datetime(data_extract['date_gmt'] + ' ' + data_extract['time_gmt'])
                output_data['sample_measurement'] = data_extract['sample_measurement']

                output_data.sort_values(by='date').to_csv(f"../data/{fname}".strip().replace(".json", ".csv"), index=False, mode='a')

                print(f"[info]: DONE processing (start={bdate}, end={edate}, state={state}, county={county}, site={site}) > CREATED {fname}")
            else:
                print(f"[warn]: UNABLE TO PROCESS (start={bdate}, end={edate}, state={state}, county={county}, site={site}) > NOT CREATED {fname}")
        except:
            print(f"[error]: UNABLE TO PROCESS (start={bdate}, end={edate}, state={state}, county={county}, site={site}) > NOT CREATED {fname}")

        time.sleep(2)
# Out:
# [info]: START processing (start=20170101, end=20171231, state=08, county=103, site=0007) > Western_CO/Piceance_Basin/RioBasin_2017payload.json
#
# [warn]: UNABLE TO PROCESS (start=20170101, end=20171231, state=08, county=103, site=0007) > NOT CREATED Western_CO/Piceance_Basin/RioBasin_2017payload.json
#
# [info]: START processing (start=20180101, end=20181231, state=08, county=103, site=0007) > Western_CO/Piceance_Basin/RioBasin_2018payload.json
#
# [warn]: UNABLE TO PROCESS (start=20180101, end=20181231, state=08, county=103, site=0007) > NOT CREATED Western_CO/Piceance_Basin/RioBasin_2018payload.json
#
# [info]: START processing (start=20190101, end=20191231, state=08, county
2021payload.json
#
# [info]: DONE processing (start=20210101, end=20211231, state=08, county=067, site=7003) > CREATED Western_CO/La_Posta/Ute3_2021payload.json
#
# [info]: START processing (start=20220101, end=20221231, state=08, county=067, site=7003) > Western_CO/La_Posta/Ute3_2022payload.json
#
# [info]: DONE processing (start=20220101, end=20221231, state=08, county=067, site=7003) > CREATED Western_CO/La_Posta/Ute3_2022payload.json
#
# [info]: START processing (start=20170101, end=20221231, state=08, county=067, site=7003) > Western_CO/La_Posta/Ute3_1722payload.json
#
# [error]: UNABLE TO PROCESS (start=20170101, end=20221231, state=08, county=067, site=7003) > NOT CREATED Western_CO/La_Posta/Ute3_1722payload.json
#
# [error]: UNABLE TO PROCESS (start=20170101, end=20221231, state=08, county=067, site=7003) > NOT CREATED Western_CO/La_Posta/Ute3_1722payload.json
#
# [info]: START processing (start=20170101, end=20171231, state=08, county=029, site=0007) > Western_CO/Paonia/Paonia_2017payload.json
#
# [warn]: UNABLE TO PROCESS (start=20170101, end=20171231, state=08, county=029, site=0007) > NOT CREATED Western_CO/Paonia/Paonia_2017payload.json
#
# [info]: START processing (start=20180101, end=20181231, state=08, county=029, site=0007) > Western_CO/Paonia/Paonia_2018payload.json
#
# [info]: DONE processing (start=20180101, end=20181231, state=08, county=029, site=0007) > CREATED Western_CO/Paonia/Paonia_2018payload.json
#
# [info]: START processing (start=20190101, end=20191231, state=08, county=029, site=0007) > Western_CO/Paonia/Paonia_2019payload.json
#
# [info]: DONE processing (start=20190101, end=20191231, state=08, county=029, site=0007) > CREATED Western_CO/Paonia/Paonia_2019payload.json
#
# [info]: START processing (start=20200101, end=20201231, state=08, county=029, site=0007) > Western_CO/Paonia/Paonia_2020payload.json
#
# [info]: DONE processing (start=20200101, end=20201231, state=08, county=029, site=0007) > CREATED Western_CO/Paonia/Paonia_2020payload.json
#
# [info]: START processing (start=20210101, end=20211231, state=08, county=029, site=0007) > Western_CO/Paonia/Paonia_2021payload.json
#
# [info]: DONE processing (start=20210101, end=20211231, state=08, county=029, site=0007) > CREATED Western_CO/Paonia/Paonia_2021payload.json
#
# [info]: START processing (start=20220101, end=20221231, state=08, county=029, site=0007) > Western_CO/Paonia/Paonia_2022payload.json
#
# [info]: DONE processing (start=20220101, end=20221231, state=08, county=029, site=0007) > CREATED Western_CO/Paonia/Paonia_2022payload.json
#
# [info]: START processing (start=20170101, end=20221231, state=08, county=029, site=0007) > Western_CO/Paonia/Paonia_1722payload.json
#
# [error]: UNABLE TO PROCESS (start=20170101, end=20221231, state=08, county=029, site=0007) > NOT CREATED Western_CO/Paonia/Paonia_1722payload.json
#
# [error]: UNABLE TO PROCESS (start=20170101, end=20221231, state=08, county=029, site=0007) > NOT CREATED Western_CO/Paonia/Paonia_1722payload.json
#
# [info]: START processing (start=20170101, end=20171231, state=08, county=097, site=0008) > Western_CO/Aspen/YBrick_2017payload.json
#
# [info]: DONE processing (start=20170101, end=20171231, state=08, county=097, site=0008) > CREATED Western_CO/Aspen/YBrick_2017payload.json
#
# [info]: START processing (start=20180101, end=20181231, state=08, county=097, site=0008) > Western_CO/Aspen/YBrick_2018payload.json
#
# [info]: DONE processing (start=20180101, end=20181231, state=08, county=097, site=0008) > CREATED Western_CO/Aspen/YBrick_2018payload.json
#
# [info]: START processing (start=20190101, end=20191231, state=08, county=097, site=0008) > Western_CO/Aspen/YBrick_2019payload.json
#
# [info]: DONE processing (start=20190101, end=20191231, state=08, county=097, site=0008) > CREATED Western_CO/Aspen/YBrick_2019payload.json
#
# [info]: START processing (start=20200101, end=20201231, state=08, county=097, site=0008) > Western_CO/Aspen/YBrick_2020payload.json
#
# [info]: DONE processing (start=20200101, end=20201231, state=08, county=097, site=0008) > CREATED Western_CO/Aspen/YBrick_2020payload.json
#
# [info]: START processing (start=20210101, end=20211231, state=08, county=097, site=0008) > Western_CO/Aspen/YBrick_2021payload.json
#
# [info]: DONE processing (start=20210101, end=20211231, state=08, county=097, site=0008) > CREATED Western_CO/Aspen/YBrick_2021payload.json
#
# [info]: START processing (start=20220101, end=20221231, state=08, county=097, site=0008) > Western_CO/Aspen/YBrick_2022payload.json
#
# [info]: DONE processing (start=20220101, end=20221231, state=08, county=097, site=0008) > CREATED Western_CO/Aspen/YBrick_2022payload.json
#
# [info]: START processing (start=20170101, end=20221231, state=08, county=097, site=0008) > Western_CO/Aspen/YBrick_1722payload.json
#
# [error]: UNABLE TO PROCESS (start=20170101, end=20221231, state=08, county=097, site=0008) > NOT CREATED Western_CO/Aspen/YBrick_1722payload.json
#
# [error]: UNABLE TO PROCESS (start=20170101, end=20221231, state=08, county=097, site=0008) > NOT CREATED Western_CO/Aspen/YBrick_1722payload.json
#
# [info]: START processing (start=20170101, end=20171231, state=08, county=031, site=0027) > Denver/I25Denver/I25D_2017payload.json
#
# [info]: DONE processing (start=20170101, end=20171231, state=08, county=031, site=0027) > CREATED Denver/I25Denver/I25D_2017payload.json
#
# [info]: START processing (start=20180101, end=20181231, state=08, county=031, site=0027) > Denver/I25Denver/I25D_2018payload.json
#
# [info]: DONE processing (start=20180101, end=20181231, state=08, county=031, site=0027) > CREATED Denver/I25Denver/I25D_2018payload.json
#
# [info]: START processing (start=20190101, end=20191231, state=08, county=031, site=0027) > Denver/I25Denver/I25D_2019payload.json
#
# [info]: DONE processing (start=20190101, end=20191231, state=08, county=031, site=0027) > CREATED Denver/I25Denver/I25D_2019payload.json
#
# [info]: START processing (start=20200101, end=20201231, state=08, county=031, site=0027) > Denver/I25Denver/I25D_2020payload.json
#
# [info]: DONE processing (start=20200101, end=20201231, state=08, county=031, site=0027) > CREATED Denver/I25Denver/I25D_2020payload.json
#
# [info]: START processing (start=20210101, end=20211231, state=08, county=031, site=0027) > Denver/I25Denver/I25D_2021payload.json
#
# [info]: DONE processing (start=20210101, end=20211231, state=08, county=031, site=0027) > CREATED Denver/I25Denver/I25D_2021payload.json
#
# [info]: START processing (start=20220101, end=20221231, state=08, county=031, site=0027) > Denver/I25Denver/I25D_2022payload.json
#
# [info]: DONE processing (start=20220101, end=20221231, state=08, county=031, site=0027) > CREATED Denver/I25Denver/I25D_2022payload.json
#
# [info]: START processing (start=20170101, end=20221231, state=08, county=031, site=0027) > Denver/I25Denver/I25D_1722payload.json
#
# [error]: UNABLE TO PROCESS (start=20170101, end=20221231, state=08, county=031, site=0027) > NOT CREATED Denver/I25Denver/I25D_1722payload.json
#
# [error]: UNABLE TO PROCESS (start=20170101, end=20221231, state=08, county=031, site=0027) > NOT CREATED Denver/I25Denver/I25D_1722payload.json
#
# [info]: START processing (start=20170101, end=20171231, state=08, county=031, site=0028) > Denver/I25Globeville/I25G_2017payload.json
#
# [info]: DONE processing (start=20170101, end=20171231, state=08, county=031, site=0028) > CREATED Denver/I25Globeville/I25G_2017payload.json
#
# [info]: START processing (start=20180101, end=20181231, state=08, county=031, site=0028) > Denver/I25Globeville/I25G_2018payload.json
#
# [info]: DONE processing (start=20180101, end=20181231, state=08, county=031, site=0028) > CREATED Denver/I25Globeville/I25G_2018payload.json
#
# [info]: START processing (start=20190101, end=20191231, state=08, county
1722payload.json
#
# [error]: UNABLE TO PROCESS (start=20170101, end=20221231, state=08, county=031, site=0013) > NOT CREATED Denver/NJH/14thAlbion_1722payload.json
#
# [info]: START processing (start=20170101, end=20171231, state=08, county=001, site=0010) > Denver/Adams_Birch/7275Birch_2017payload.json
#
# [warn]: UNABLE TO PROCESS (start=20170101, end=20171231, state=08, county=001, site=0010) > NOT CREATED Denver/Adams_Birch/7275Birch_2017payload.json
#
# [info]: START processing (start=20180101, end=20181231, state=08, county=001, site=0010) > Denver/Adams_Birch/7275Birch_2018payload.json
#
# [warn]: UNABLE TO PROCESS (start=20180101, end=20181231, state=08, county=001, site=0010) > NOT CREATED Denver/Adams_Birch/7275Birch_2018payload.json
#
# [info]: START processing (start=20190101, end=20191231, state=08, county=001, site=0010) > Denver/Adams_Birch/7275Birch_2019payload.json
#
# [warn]: UNABLE TO PROCESS (start=20190101, end=20191231, state=08, county=001, site=0010) > NOT CREATED Denver/Adams_Birch/7275Birch_2019payload.json
#
# [info]: START processing (start=20200101, end=20201231, state=08, county=001, site=0010) > Denver/Adams_Birch/7275Birch_2020payload.json
#
# [warn]: UNABLE TO PROCESS (start=20200101, end=20201231, state=08, county=001, site=0010) > NOT CREATED Denver/Adams_Birch/7275Birch_2020payload.json
#
# [info]: START processing (start=20210101, end=20211231, state=08, county=001, site=0010) > Denver/Adams_Birch/7275Birch_2021payload.json
#
# [info]: DONE processing (start=20210101, end=20211231, state=08, county=001, site=0010) > CREATED Denver/Adams_Birch/7275Birch_2021payload.json
#
# [info]: START processing (start=20220101, end=20221231, state=08, county=001, site=0010) > Denver/Adams_Birch/7275Birch_2022payload.json
#
# [info]: DONE processing (start=20220101, end=20221231, state=08, county=001, site=0010) > CREATED Denver/Adams_Birch/7275Birch_2022payload.json
#
# [info]: START processing (start=20170101, end=20221231, state=08, county=001, site=0010) > Denver/Adams_Birch/7275Birch_1722payload.json
#
# [error]: UNABLE TO PROCESS (start=20170101, end=20221231, state=08, county=001, site=0010) > NOT CREATED Denver/Adams_Birch/7275Birch_1722payload.json
#
# [error]: UNABLE TO PROCESS (start=20170101, end=20221231, state=08, county=001, site=0010) > NOT CREATED Denver/Adams_Birch/7275Birch_1722payload.json
#
# [info]: START processing (start=20170101, end=20171231, state=08, county=001, site=0008) > Denver/Adams_Birch/7275Birch0008_2017payload.json
#
# [info]: DONE processing (start=20170101, end=20171231, state=08, county=001, site=0008) > CREATED Denver/Adams_Birch/7275Birch0008_2017payload.json
#
# [info]: START processing (start=20180101, end=20181231, state=08, county=001, site=0008) > Denver/Adams_Birch/7275Birch0008_2018payload.json
#
# [info]: DONE processing (start=20180101, end=20181231, state=08, county=001, site=0008) > CREATED Denver/Adams_Birch/7275Birch0008_2018payload.json
#
# [info]: START processing (start=20190101, end=20191231, state=08, county=001, site=0008) > Denver/Adams_Birch/7275Birch0008_2019payload.json
#
# [info]: DONE processing (start=20190101, end=20191231, state=08, county=001, site=0008) > CREATED Denver/Adams_Birch/7275Birch0008_2019payload.json
#
# [info]: START processing (start=20200101, end=20201231, state=08, county=001, site=0008) > Denver/Adams_Birch/7275Birch0008_2020payload.json
#
# [info]: DONE processing (start=20200101, end=20201231, state=08, county=001, site=0008) > CREATED Denver/Adams_Birch/7275Birch0008_2020payload.json
#
# [info]: START processing (start=20210101, end=20211231, state=08, county=001, site=0008) > Denver/Adams_Birch/7275Birch0008_2021payload.json
#
# [warn]: UNABLE TO PROCESS (start=20210101, end=20211231, state=08, county=001, site=0008) > NOT CREATED Denver/Adams_Birch/7275Birch0008_2021payload.json
#
# [info]: START processing (start=20220101, end=20221231, state=08, county=001, site=0008) > Denver/Adams_Birch/7275Birch0008_2022payload.json
#
# [warn]: UNABLE TO PROCESS (start=20220101, end=20221231, state=08, county=001, site=0008) > NOT CREATED Denver/Adams_Birch/7275Birch0008_2022payload.json
#
# [info]: START processing (start=20170101, end=20221231, state=08, county=001, site=0008) > Denver/Adams_Birch/7275Birch0008_1722payload.json
#
# [error]: UNABLE TO PROCESS (start=20170101, end=20221231, state=08, county=001, site=0008) > NOT CREATED Denver/Adams_Birch/7275Birch0008_1722payload.json
#
# [error]: UNABLE TO PROCESS (start=20170101, end=20221231, state=08, county=001, site=0008) > NOT CREATED Denver/Adams_Birch/7275Birch0008_1722payload.json
#
# [info]: START processing (start=20170101, end=20171231, state=08, county=013, site=1001) > Front_Range/FRBoulder/2017payload.json
#
# [info]: DONE processing (start=20170101, end=20171231, state=08, county=013, site=1001) > CREATED Front_Range/FRBoulder/2017payload.json
#
# [info]: START processing (start=20180101, end=20181231, state=08, county=013, site=1001) > Front_Range/FRBoulder/2018payload.json
#
# [info]: DONE processing (start=20180101, end=20181231, state=08, county=013, site=1001) > CREATED Front_Range/FRBoulder/2018payload.json
#
# [info]: START processing (start=20190101, end=20191231, state=08, county=013, site=1001) > Front_Range/FRBoulder/2019payload.json
#
# [info]: DONE processing (start=20190101, end=20191231, state=08, county=013, site=1001) > CREATED Front_Range/FRBoulder/2019payload.json
#
# [info]: START processing (start=20200101, end=20201231, state=08, county=013, site=1001) > Front_Range/FRBoulder/2020payload.json
#
# [info]: DONE processing (start=20200101, end=20201231, state=08, county=013, site=1001) > CREATED Front_Range/FRBoulder/2020payload.json
#
# [info]: START processing (start=20210101, end=20211231, state=08, county=013, site=1001) > Front_Range/FRBoulder/2021payload.json
#
# [info]: DONE processing (start=20210101, end=20211231, state=08, county=013, site=1001) > CREATED Front_Range/FRBoulder/2021payload.json
#
# [info]: START processing (start=20220101, end=20221231, state=08, county=013, site=1001) > Front_Range/FRBoulder/2022payload.json
#
# [info]: DONE processing (start=20220101, end=20221231, state=08, county=013, site=1001) > CREATED Front_Range/FRBoulder/2022payload.json
#
# [info]: START processing (start=20170101, end=20221231, state=08, county=013, site=1001) > Front_Range/FRBoulder/1722payload.json
#
# [error]: UNABLE TO PROCESS (start=20170101, end=20221231, state=08, county=013, site=1001) > NOT CREATED Front_Range/FRBoulder/1722payload.json
#
# [error]: UNABLE TO PROCESS (start=20170101, end=20221231, state=08, county=013, site=1001) > NOT CREATED Front_Range/FRBoulder/1722payload.json
#
# [info]: START processing (start=20170101, end=20171231, state=08, county=013, site=0012) > Front_Range/FRBoulderCmmrce/Chamber_2017payload.json
#
# [info]: DONE processing (start=20170101, end=20171231, state=08, county=013, site=0012) > CREATED Front_Range/FRBoulderCmmrce/Chamber_2017payload.json
#
# [info]: START processing (start=20180101, end=20181231, state=08, county=013, site=0012) > Front_Range/FRBoulderCmmrce/Chamber_2018payload.json
#
# [info]: DONE processing (start=20180101, end=20181231, state=08, county=013, site=0012) > CREATED Front_Range/FRBoulderCmmrce/Chamber_2018payload.json
#
# [info]: START processing (start=20190101, end=20191231, state=08, county=013, site=0012) > Front_Range/FRBoulderCmmrce/Chamber_2019payload.json
#
# [info]: DONE processing (start=20190101, end=20191231, state=08, county=013, site=0012) > CREATED Front_Range/FRBoulderCmmrce/Chamber_2019payload.json
#
# [info]: START processing (start=20200101, end=20201231, state=08, county=013, site=0012) > Front_Range/FRBoulderCmmrce/Chamber_2020payload.json
#
# [info]: DONE processing (start=20200101, end=20201231, state=08, county=013, site=0012) > CREATED Front_Range/FRBoulderCmmrce/Chamber_2020payload.json
#
# [info]: START processing (start=20210101, end=20211231, state=08, county=013, site=0012) > Front_Range/FRBoulderCmmrce/Chamber_2021payload.json
#
# [info]: DONE processing (start=20210101, end=20211231, state=08, county=013, site=0012) > CREATED Front_Range/FRBoulderCmmrce/Chamber_2021payload.json
#
# [info]: START processing (start=20220101, end=20221231, state=08, county=013, site=0012) > Front_Range/FRBoulderCmmrce/Chamber_2022payload.json
#
# [info]: DONE processing (start=20220101, end=20221231, state=08, county=013, site=0012) > CREATED Front_Range/FRBoulderCmmrce/Chamber_2022payload.json
#
# [info]: START processing (start=20170101, end=20221231, state=08, county=013, site=0012) > Front_Range/FRBoulderCmmrce/Chamber_1722payload.json
#
# [error]: UNABLE TO PROCESS (start=20170101, end=20221231, state=08, county=013, site=0012) > NOT CREATED Front_Range/FRBoulderCmmrce/Chamber_1722payload.json
#
# [error]: UNABLE TO PROCESS (start=20170101, end=20221231, state=08, county=013, site=0012) > NOT CREATED Front_Range/FRBoulderCmmrce/Chamber_1722payload.json
#
# [info]: START processing (start=20170101, end=20171231, state=08, county=013, site=0003) > Front_Range/FRLongmont/Lngmnt_2017payload.json
#
# [info]: DONE processing (start=20170101, end=20171231, state=08, county=013, site=0003) > CREATED Front_Range/FRLongmont/Lngmnt_2017payload.json
#
# [info]: START processing (start=20180101, end=20181231, state=08, county=013, site=0003) > Front_Range/FRLongmont/Lngmnt_2018payload.json
#
# [info]: DONE processing (start=20180101, end=20181231, state=08, county=013, site=0003) > CREATED Front_Range/FRLongmont/Lngmnt_2018payload.json
#
# [info]: START processing (start=20190101, end=20191231, state=08, county=013, site=0003) > Front_Range/FRLongmont/Lngmnt_2019payload.json
#
# [info]: DONE processing (start=20190101, end=20191231, state=08, county=013, site=0003) > CREATED Front_Range/FRLongmont/Lngmnt_2019payload.json
#
# [info]: START processing (start=20200101, end=20201231, state=08, county=013, site=0003) > Front_Range/FRLongmont/Lngmnt_2020payload.json
#
# [info]: DONE processing (start=20200101, end=20201231, state=08, county=013, site=0003) > CREATED Front_Range/FRLongmont/Lngmnt_2020payload.json
#
# [info]: START processing (start=20210101, end=20211231, state=08, county=013, site=0003) > Front_Range/FRLongmont/Lngmnt_2021payload.json
#
# [info]: DONE processing (start=20210101, end=20211231, state=08, county=013, site=0003) > CREATED Front_Range/FRLongmont/Lngmnt_2021payload.json
#
# [info]: START processing (start=20220101, end=20221231, state=08, county=013, site=0003) > Front_Range/FRLongmont/Lngmnt_2022payload.json
#
# [info]: DONE processing (start=20220101, end=20221231, state=08, county=013, site=0003) > CREATED Front_Range/FRLongmont/Lngmnt_2022payload.json
#
# [info]: START processing (start=20170101, end=20221231, state=08, county=013, site=0003) > Front_Range/FRLongmont/Lngmnt_1722payload.json
#
# [error]: UNABLE TO PROCESS (start=20170101, end=20221231, state=08, county=013, site=0003) > NOT CREATED Front_Range/FRLongmont/Lngmnt_1722payload.json
#
# [error]: UNABLE TO PROCESS (start=20170101, end=20221231, state=08, county=013, site=0003) > NOT CREATED Front_Range/FRLongmont/Lngmnt_1722payload.json
#
# [info]: START processing (start=20170101, end=20171231, state=08, county=035, site=0004) > Front_Range/FRLittleton/Roxboro_2017payload.json
#
# [info]: DONE processing (start=20170101, end=20171231, state=08, county=035, site=0004) > CREATED Front_Range/FRLittleton/Roxboro_2017payload.json
#
# [info]: START processing (start=20180101, end=20181231, state=08, county=035, site=0004) > Front_Range/FRLittleton/Roxboro_2018payload.json
#
# [info]: DONE processing (start=20180101, end=20181231, state=08, county=035, site=0004) > CREATED Front_Range/FRLittleton/Roxboro_2018payload.json
#
# [info]: START processing (start=20190101, end=20191231, state=08, county=035, site=0004) > Front_Range/FRLittleton/Roxboro_2019payload.json
#
# [info]: DONE processing (start=20190101, end=20191231, state=08, county=035, site=0004) > CREATED Front_Range/FRLittleton/Roxboro_2019payload.json
#
# [info]: START processing (start=20200101, end=20201231, state=08, county=035, site=0004) > Front_Range/FRLittleton/Roxboro_2020payload.json
#
# [info]: DONE processing (start=20200101, end=20201231, state=08, county=035, site=0004) > CREATED Front_Range/FRLittleton/Roxboro_2020payload.json
#
# [info]: START processing (start=20210101, end=20211231, state=08, county=035, site=0004) > Front_Range/FRLittleton/Roxboro_2021payload.json
#
# [info]: DONE processing (start=20210101, end=20211231, state=08, county=035, site=0004) > CREATED Front_Range/FRLittleton/Roxboro_2021payload.json
#
# [info]: START processing (start=20220101, end=20221231, state=08, county=035, site=0004) > Front_Range/FRLittleton/Roxboro_2022payload.json
#
# [info]: DONE processing (start=20220101, end=20221231, state=08, county=035, site=0004) > CREATED Front_Range/FRLittleton/Roxboro_2022payload.json
#
# [info]: START processing (start=20170101, end=20221231, state=08, county=035, site=0004) > Front_Range/FRLittleton/Roxboro_1722payload.json
#
# [error]: UNABLE TO PROCESS (start=20170101, end=20221231, state=08, county=035, site=0004) > NOT CREATED Front_Range/FRLittleton/Roxboro_1722payload.json
#
# [error]: UNABLE TO PROCESS (start=20170101, end=20221231, state=08, county=035, site=0004) > NOT CREATED Front_Range/FRLittleton/Roxboro_1722payload.json
#
# [info]: START processing (start=20170101, end=20171231, state=08, county=005, site=0005) > Front_Range/FRLittletonACC/ACC_2017payload.json
#
# [info]: DONE processing (start=20170101, end=20171231, state=08, county=005, site=0005) > CREATED Front_Range/FRLittletonACC/ACC_2017payload.json
#
# [info]: START processing (start=20180101, end=20181231, state=08, county=005, site=0005) > Front_Range/FRLittletonACC/ACC_2018payload.json
#
# [info]: DONE processing (start=20180101, end=20181231, state=08, county=005, site=0005) > CREATED Front_Range/FRLittletonACC/ACC_2018payload.json
#
# [info]: START processing (start=20190101, end=20191231, state=08, county=005, site=0005) > Front_Range/FRLittletonACC/ACC_2019payload.json
#
# [info]: DONE processing (start=20190101, end=20191231, state=08, county=005, site=0005) > CREATED Front_Range/FRLittletonACC/ACC_2019payload.json
#
# [info]: START processing (start=20200101, end=20201231, state=08, county=005, site=0005) > Front_Range/FRLittletonACC/ACC_2020payload.json
#
# [info]: DONE processing (start=20200101, end=20201231, state=08, county=005, site=0005) > CREATED Front_Range/FRLittletonACC/ACC_2020payload.json
#
# [info]: START processing (start=20210101, end=20211231, state=08, county=005, site=0005) > Front_Range/FRLittletonACC/ACC_2021payload.json
#
# [info]: DONE processing (start=20210101, end=20211231, state=08, county=005, site=0005) > CREATED Front_Range/FRLittletonACC/ACC_2021payload.json
#
# [info]: START processing (start=20220101, end=20221231, state=08, county=005, site=0005) > Front_Range/FRLittletonACC/ACC_2022payload.json
#
# [info]: DONE processing (start=20220101, end=20221231, state=08, county=005, site=0005) > CREATED Front_Range/FRLittletonACC/ACC_2022payload.json
#
# [info]: START processing (start=20170101, end=20221231, state=08, county=005, site=0005) > Front_Range/FRLittletonACC/ACC_1722payload.json
#
# [error]: UNABLE TO PROCESS (start=20170101, end=20221231, state=08, county=005, site=0005) > NOT CREATED Front_Range/FRLittletonACC/ACC_1722payload.json
#
# [error]: UNABLE TO PROCESS (start=20170101, end=20221231, state=08, county=005, site=0005) > NOT CREATED Front_Range/FRLittletonACC/ACC_1722payload.json
#
# [info]: START processing (start=20170101, end=20171231, state=08, county=069, site=0009) > Front_Range/FRFtCollins/FTCol_2017payload.json
#
# [info]: DONE processing (start=20170101, end=20171231, state=08, county=069, site=0009) > CREATED Front_Range/FRFtCollins/FTCol_2017payload.json
#
# [info]: START processing (start=20180101, end=20181231, state=08, county=069, site=0009) > Front_Range/FRFtCollins/FTCol_2018payload.json
#
# [info]: DONE processing (start=20180101, end=20181231, state=08, county=069, site=0009) > CREATED Front_Range/FRFtCollins/FTCol_2018payload.json
#
# [info]: START processing (start=20190101, end=20191231, state=08, county=069, site=0009) > Front_Range/FRFtCollins/FTCol_2019payload.json
#
# [info]: DONE processing (start=20190101, end=20191231, state=08, county=069, site=0009) > CREATED Front_Range/FRFtCollins/FTCol_2019payload.json
#
# [info]: START processing (start=20200101, end=20201231, state=08, county=069, site=0009) > Front_Range/FRFtCollins/FTCol_2020payload.json
#
# [info]: DONE processing (start=20200101, end=20201231, state=08, county=069, site=0009) > CREATED Front_Range/FRFtCollins/FTCol_2020payload.json
#
# [info]: START processing (start=20210101, end=20211231, state=08, county=069, site=0009) > Front_Range/FRFtCollins/FTCol_2021payload.json
#
# [info]: DONE processing (start=20210101, end=20211231, state=08, county=069, site=0009) > CREATED Front_Range/FRFtCollins/FTCol_2021payload.json
#
# [info]: START processing (start=20220101, end=20221231, state=08, county=069, site=0009) > Front_Range/FRFtCollins/FTCol_2022payload.json
#
# [info]: DONE processing (start=20220101, end=20221231, state=08, county=069, site=0009) > CREATED Front_Range/FRFtCollins/FTCol_2022payload.json
#
# [info]: START processing (start=20170101, end=20221231, state=08, county=069, site=0009) > Front_Range/FRFtCollins/FTCol_1722payload.json
#
# [error]: UNABLE TO PROCESS (start=20170101, end=20221231, state=08, county=069, site=0009) > NOT CREATED Front_Range/FRFtCollins/FTCol_1722payload.json
#
# [error]: UNABLE TO PROCESS (start=20170101, end=20221231, state=08, county=069, site=0009) > NOT CREATED Front_Range/FRFtCollins/FTCol_1722payload.json
#
# [info]: START processing (start=20170101, end=20171231, state=08, county=123, site=0006) > Front_Range/FRGreely/Grly_2017payload.json
#
# [info]: DONE processing (start=20170101, end=20171231, state=08, county=123, site=0006) > CREATED Front_Range/FRGreely/Grly_2017payload.json
#
# [info]: START processing (start=20180101, end=20181231, state=08, county=123, site=0006) > Front_Range/FRGreely/Grly_2018payload.json
#
# [info]: DONE processing (start=20180101, end=20181231, state=08, county=123, site=0006) > CREATED Front_Range/FRGreely/Grly_2018payload.json
#
# [info]: START processing (start=20190101, end=20191231, state=08, county=123, site=0006) > Front_Range/FRGreely/Grly_2019payload.json
#
# [info]: DONE processing (start=20190101, end=20191231, state=08, county=123, site=0006) > CREATED Front_Range/FRGreely/Grly_2019payload.json
#
# [info]: START processing (start=20200101, end=20201231, state=08, county=123, site=0006) > Front_Range/FRGreely/Grly_2020payload.json
#
# [info]: DONE processing (start=20200101, end=20201231, state=08, county=123, site=0006) > CREATED Front_Range/FRGreely/Grly_2020payload.json
#
# [info]: START processing (start=20210101, end=20211231, state=08, county=123, site=0006) > Front_Range/FRGreely/Grly_2021payload.json
#
# [info]: DONE processing (start=20210101, end=20211231, state=08, county=123, site=0006) > CREATED Front_Range/FRGreely/Grly_2021payload.json
#
# [info]: START processing (start=20220101, end=20221231, state=08, county=123, site=0006) > Front_Range/FRGreely/Grly_2022payload.json
#
# [info]: DONE processing (start=20220101, end=20221231, state=08, county=123, site=0006) > CREATED Front_Range/FRGreely/Grly_2022payload.json
#
# [info]: START processing (start=20170101, end=20221231, state=08, county=123, site=0006) > Front_Range/FRGreely/Grly_1722payload.json
#
# [error]: UNABLE TO PROCESS (start=20170101, end=20221231, state=08, county=123, site=0006) > NOT CREATED Front_Range/FRGreely/Grly_1722payload.json
#
# [error]: UNABLE TO PROCESS (start=20170101, end=20221231, state=08, county=123, site=0006) > NOT CREATED Front_Range/FRGreely/Grly_1722payload.json
#
# [info]: START processing (start=20170101, end=20171231, state=08, county=123, site=0008) > Front_Range/FRPlatteville/MS_2017payload.json
#
# [info]: DONE processing (start=20170101, end=20171231, state=08, county=123, site=0008) > CREATED Front_Range/FRPlatteville/MS_2017payload.json
#
# [info]: START processing (start=20180101, end=20181231, state=08, county=123, site=0008) > Front_Range/FRPlatteville/MS_2018payload.json
#
# [info]: DONE processing (start=20180101, end=20181231, state=08, county=123, site=0008) > CREATED Front_Range/FRPlatteville/MS_2018payload.json
#
# [info]: START processing (start=20190101, end=20191231, state=08, county=123, site=0008) > Front_Range/FRPlatteville/MS_2019payload.json
#
# [info]: DONE processing (start=20190101, end=20191231, state=08, county=123, site=0008) > CREATED Front_Range/FRPlatteville/MS_2019payload.json
#
# [info]: START processing (start=20200101, end=20201231, state=08, county=123, site=0008) > Front_Range/FRPlatteville/MS_2020payload.json
#
# [info]: DONE processing (start=20200101, end=20201231, state=08, county=123, site=0008) > CREATED Front_Range/FRPlatteville/MS_2020payload.json
#
# [info]: START processing (start=20210101, end=20211231, state=08, county=123, site=0008) > Front_Range/FRPlatteville/MS_2021payload.json
#
# [info]: DONE processing (start=20210101, end=20211231, state=08, county=123, site=0008) > CREATED Front_Range/FRPlatteville/MS_2021payload.json
#
# [info]: START processing (start=20220101, end=20221231, state=08, county=123, site=0008) > Front_Range/FRPlatteville/MS_2022payload.json
#
# [info]: DONE processing (start=20220101, end=20221231, state=08, county=123, site=0008) > CREATED Front_Range/FRPlatteville/MS_2022payload.json
#
# [info]: START processing (start=20170101, end=20221231, state=08, county=123, site=0008) > Front_Range/FRPlatteville/MS_1722payload.json
#
# [error]: UNABLE TO PROCESS (start=20170101, end=20221231, state=08, county=123, site=0008) > NOT CREATED Front_Range/FRPlatteville/MS_1722payload.json
#
# [error]: UNABLE TO PROCESS (start=20170101, end=20221231, state=08, county=123, site=0008) > NOT CREATED Front_Range/FRPlatteville/MS_1722payload.json
#
# [info]: START processing (start=20170101, end=20171231, state=08, county=041, site=0017) > Front_Range/FRColoradoSprings/CS_2017payload.json
#
# [info]: DONE processing (start=20170101, end=20171231, state=08, county=041, site=0017) > CREATED Front_Range/FRColoradoSprings/CS_2017payload.json
#
# [info]: START processing (start=20180101, end=20181231, state=08, county=041, site=0017) > Front_Range/FRColoradoSprings/CS_2018payload.json
#
# [info]: DONE processing (start=20180101, end=20181231, state=08, county=041, site=0017) > CREATED Front_Range/FRColoradoSprings/CS_2018payload.json
#
# [info]: START processing (start=20190101, end=20191231, state=08, county=041, site=0017) > Front_Range/FRColoradoSprings/CS_2019payload.json
#
# [info]: DONE processing (start=20190101, end=20191231, state=08, county=041, site=0017) > CREATED Front_Range/FRColoradoSprings/CS_2019payload.json
#
# [info]: START processing (start=20200101, end=20201231, state=08, county=041, site=0017) > Front_Range/FRColoradoSprings/CS_2020payload.json
#
# [info]: DONE processing (start=20200101, end=20201231, state=08, county=041, site=0017) > CREATED Front_Range/FRColoradoSprings/CS_2020payload.json
#
# [info]: START processing (start=20210101, end=20211231, state=08, county=041, site=0017) > Front_Range/FRColoradoSprings/CS_2021payload.json
#
# [info]: DONE processing (start=20210101, end=20211231, state=08, county=041, site=0017) > CREATED Front_Range/FRColoradoSprings/CS_2021payload.json
#
# [info]: START processing (start=20220101, end=20221231, state=08, county=041, site=0017) > Front_Range/FRColoradoSprings/CS_2022payload.json
#
# [info]: DONE processing (start=20220101, end=20221231, state=08, county=041, site=0017) > CREATED Front_Range/FRColoradoSprings/CS_2022payload.json
#
# [info]: START processing (start=20170101, end=20221231, state=08, county=041, site=0017) > Front_Range/FRColoradoSprings/CS_1722payload.json
#
# [error]: UNABLE TO PROCESS (start=20170101, end=20221231, state=08, county=041, site=0017) > NOT CREATED Front_Range/FRColoradoSprings/CS_1722payload.json
#
# [error]: UNABLE TO PROCESS (start=20170101, end=20221231, state=08, county=041, site=0017) > NOT CREATED Front_Range/FRColoradoSprings/CS_1722payload.json
#
# [info]: START processing (start=20170101, end=20171231, state=08, county=101, site=0015) > Front_Range/FRPueblo/FtnSchl_2017payload.json
#
# [info]: DONE processing (start=20170101, end=20171231, state=08, county=101, site=0015) > CREATED Front_Range/FRPueblo/FtnSchl_2017payload.json
#
# [info]: START processing (start=20180101, end=20181231, state=08, county=101, site=0015) > Front_Range/FRPueblo/FtnSchl_2018payload.json
#
# [info]: DONE processing (start=20180101, end=20181231, state=08, county=101, site=0015) > CREATED Front_Range/FRPueblo/FtnSchl_2018payload.json
#
# [info]: START processing (start=20190101, end=20191231, state=08, county=101, site=0015) > Front_Range/FRPueblo/FtnSchl_2019payload.json
#
# [info]: DONE processing (start=20190101, end=20191231, state=08, county=101, site=0015) > CREATED Front_Range/FRPueblo/FtnSchl_2019payload.json
#
# [info]: START processing (start=20200101, end=20201231, state=08, county=101, site=0015) > Front_Range/FRPueblo/FtnSchl_2020payload.json
#
# [info]: DONE processing (start=20200101, end=20201231, state=08, county=101, site=0015) > CREATED Front_Range/FRPueblo/FtnSchl_2020payload.json
#
# [info]: START processing (start=20210101, end=20211231, state=08, county=101, site=0015) > Front_Range/FRPueblo/FtnSchl_2021payload.json
#
# [info]: DONE processing (start=20210101, end=20211231, state=08, county=101, site=0015) > CREATED Front_Range/FRPueblo/FtnSchl_2021payload.json
#
# [info]: START processing (start=20220101, end=20221231, state=08, county=101, site=0015) > Front_Range/FRPueblo/FtnSchl_2022payload.json
#
# [info]: DONE processing (start=20220101, end=20221231, state=08, county=101, site=0015) > CREATED Front_Range/FRPueblo/FtnSchl_2022payload.json
#
# [info]: START processing (start=20170101, end=20221231, state=08, county=101, site=0015) > Front_Range/FRPueblo/FtnSchl_1722payload.json
#
# [error]: UNABLE TO PROCESS (start=20170101, end=20221231, state=08, county=101, site=0015) > NOT CREATED Front_Range/FRPueblo/FtnSchl_1722payload.json
